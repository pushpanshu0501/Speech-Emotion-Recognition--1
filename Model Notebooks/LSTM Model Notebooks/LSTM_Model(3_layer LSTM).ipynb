# %%
import pandas as pd
import numpy as np

import sys
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split


import keras
from keras.callbacks import ReduceLROnPlateau
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, BatchNormalization
from keras.utils import np_utils
from keras.utils.np_utils import to_categorical
from keras.callbacks import ModelCheckpoint

import tensorflow as tf

import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
from google.colab import drive
drive.mount('/content/drive')

Features = pd.read_csv('/content/drive/MyDrive/features_dataset.csv')
Features.head()
# Features.shape
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Unnamed: 0         0         1  ...       159           160  labels
# 0           0  0.272267  0.689451  ...  0.000143  1.498768e-05   angry
# 1           1  0.262035  0.603476  ...  0.000011  8.432723e-07    calm
# 2           2  0.195466  0.628032  ...  0.000031  2.326331e-06     sad
# 3           3  0.173769  0.720864  ...  0.000074  4.691918e-06    fear
# 4           4  0.207284  0.692981  ...  0.000008  4.218449e-07     sad
#
# [5 rows x 163 columns]

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
import pandas as pd

# %%
X = Features.iloc[: ,:-1].values
Y = Features['labels'].values

# %%
# As this is a multiclass classification problem onehotencoding our Y.
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# %%
# splitting data
x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state=1, shuffle=True, test_size=0.25)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((1080, 162), (1080, 8), (360, 162), (360, 8))

# %%
# scaling our data with sklearn's Standard scaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((1080, 162), (1080, 8), (360, 162), (360, 8))

# %%
print('Train dimension:')
print(x_train.shape)
print('Test dimension:')
print(x_test.shape)

print('Train labels dimension:')
print(y_train.shape)
print('Test labels dimension:')
print(y_test.shape)
# Out:
# Train dimension:
# (1080, 162)
# Test dimension:
# (360, 162)
# Train labels dimension:
# (1080, 8)
# Test labels dimension:
# (360, 8)

# %%
# making our data compatible to model.
x_train = np.expand_dims(x_train, axis=2)
x_test = np.expand_dims(x_test, axis=2)

print((x_train.shape,y_test.shape))
# Out:
# ((1080, 162, 1), (360, 8))

# %%
# LSTM Classifier
import keras
from keras.models import Sequential
from keras.layers import *
from keras.regularizers import l2, l1, l1_l2

from tensorflow.keras import layers,regularizers,models
from tensorflow import keras

# %%
# model = Sequential()
# model.add(BatchNormalization(axis=-1, input_shape=(x_train.shape[1], 1)))
# model.add(LSTM(128,dropout=0.4, recurrent_dropout=0.2, return_sequences=True))

# model.add(Dense(64))
# model.add(Dropout(0.4))
# model.add(Activation('relu'))
# model.add(Dense(64))
# model.add(Dropout(0.4))
# model.add(Activation('relu'))
# model.add(Dense(64))
# model.add(Dropout(0.4))
# model.add(Activation('relu'))

# # model.add(LSTM(64, dropout=0.1, recurrent_dropout=0.2, return_sequences=True))
# model.add(Flatten())
# model.add(Dense(8))
# model.add(Activation('softmax'))

model = Sequential()
model.add(BatchNormalization(axis=-1, input_shape=(x_train.shape[1], 1)))
model.add(LSTM(256, return_sequences=True))
model.add(Dropout(0.1))
model.add(LSTM(32, return_sequences=True))
model.add(Dropout(0.1))
model.add(LSTM(32, return_sequences=True))
model.add(BatchNormalization())
# model.add(Dropout(0.2))
model.add(Flatten())

# model.add(Dense(64))
# model.add(Activation('relu'))
# model.add(Dropout(0.5))
# model.add(BatchNormalization())
# model.add(Dense(32))
# model.add(Activation('relu'))
# model.add(Dropout(0.5))


model.add(Dense(8))
model.add(Activation('softmax'))


# model = models.Sequential([
#         layers.BatchNormalization(input_shape=(x_train.shape[1], 1)),
#         layers.LSTM(256,dropout=0.2,recurrent_dropout=0.2,activation=None,return_sequences=True,kernel_regularizer=regularizers.l2(1e-5)),
#         layers.LSTM(128,dropout=0.2,recurrent_dropout=0.2,return_sequences=True,kernel_regularizer=regularizers.l2(1e-5)),
#         layers.LSTM(32,dropout=0.2,recurrent_dropout=0.2,return_sequences=True,activation=None,kernel_regularizer=regularizers.l2(1e-5)),
#         layers.BatchNormalization(),

#         layers.Flatten(),
#         layers.Dense(256,activation='relu',kernel_regularizer=regularizers.l2(1e-5)),
#         layers.Dropout(0.2),
#         layers.BatchNormalization(),
#         layers.Dense(8,activation='softmax'),
# ])

# opt = keras.optimizers.Adam(learning_rate=0.001)
# Configures the model for training
model.compile(loss='categorical_crossentropy', optimizer='RMSProp', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_19 (Batc (None, 162, 1)            4
# _________________________________________________________________
# lstm_26 (LSTM)               (None, 162, 256)          264192
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 162, 256)          0
# _________________________________________________________________
# lstm_27 (LSTM)               (None, 162, 32)           36992
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 162, 32)           0
# _________________________________________________________________
# lstm_28 (LSTM)               (None, 162, 32)           8320
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 162, 32)           128
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 5184)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 8)                 41480
# _________________________________________________________________
# activation_8 (Activation)    (None, 8)                 0
# =================================================================
# Total params: 351,116
# Trainable params: 351,050
# Non-trainable params: 66
# _________________________________________________________________

# %%
# Training the model
history=model.fit(x_train, y_train, batch_size=32, epochs=200, validation_data=(x_test, y_test), shuffle=True)
# Out:
# Epoch 1/200
# 34/34 [==============================] - 13s 194ms/step - loss: 2.6029 - accuracy: 0.2187 - val_loss: 2.0089 - val_accuracy: 0.1833
# Epoch 2/200
# 34/34 [==============================] - 5s 147ms/step - loss: 1.7903 - accuracy: 0.3338 - val_loss: 1.9984 - val_accuracy: 0.1389
# Epoch 3/200
# 34/34 [==============================] - 5s 145ms/step - loss: 1.7064 - accuracy: 0.3744 - val_loss: 2.0064 - val_accuracy: 0.1528
# Epoch 4/200
# 34/34 [==============================] - 5s 143ms/step - loss: 1.6164 - accuracy: 0.4042 - val_loss: 1.9918 - val_accuracy: 0.1278
# Epoch 5/200
# 34/34 [==============================] - 5s 142ms/step - loss: 1.5660 - accuracy: 0.4256 - val_loss: 1.9626 - val_accuracy: 0.1278
# Epoch 6/200
# 34/34 [==============================] - 5s 142ms/step - loss: 1.5443 - accuracy: 0.4423 - val_loss: 1.9435 - val_accuracy: 0.1639
# Epoch 7/200
# 34/34 [==============================] - 5s 141ms/step - loss: 1.4501 - accuracy: 0.4798 - val_loss: 1.8855 - val_accuracy: 0.2056
# Epoch 8/200
# 34/34 [==============================] - 5s 140ms/step - loss: 1.4565 - accuracy: 0.4685 - val_loss: 1.9145 - val_accuracy: 0.1278
# Epoch 9/200
# 34/34 [==============================] - 5s 140ms/step - loss: 1.4002 - accuracy: 0.4765 - val_loss: 1.8319 - val_accuracy: 0.3417
# Epoch 10/200
# 34/34 [==============================] - 5s 141ms/step - loss: 1.3991 - accuracy: 0.4828 - val_loss: 1.8036 - val_accuracy: 0.2806
# Epoch 11/200
# 34/34 [==============================] - 5s 140ms/step - loss: 1.4113 - accuracy: 0.4820 - val_loss: 1.7631 - val_accuracy: 0.3833
# Epoch 12/200
# 34/34 [==============================] - 5s 140ms/step - loss: 1.3617 - accuracy: 0.4880 - val_loss: 1.6724 - val_accuracy: 0.3861
# Epoch 13/200
# 34/34 [==============================] - 5s 140ms/step - loss: 1.3040 - accuracy: 0.5201 - val_loss: 1.6777 - val_accuracy: 0.3611
# Epoch 14/200
# 34/34 [==============================] - 5s 138ms/step - loss: 1.3129 - accuracy: 0.5409 - val_loss: 1.6792 - val_accuracy: 0.3528
# Epoch 15/200
# 34/34 [==============================] - 5s 138ms/step - loss: 1.2567 - accuracy: 0.5739 - val_loss: 1.5131 - val_accuracy: 0.4611
# Epoch 16/200
# 34/34 [==============================] - 5s 138ms/step - loss: 1.3461 - accuracy: 0.5303 - val_loss: 1.5784 - val_accuracy: 0.3778
# Epoch 17/200
# 34/34 [==============================] - 5s 137ms/step - loss: 1.1864 - accuracy: 0.5691 - val_loss: 1.5433 - val_accuracy: 0.3833
# Epoch 18/200
# 34/34 [==============================] - 5s 137ms/step - loss: 1.2295 - accuracy: 0.5232 - val_loss: 1.5122 - val_accuracy: 0.4250
# Epoch 19/200
# 34/34 [==============================] - 5s 137ms/step - loss: 1.1345 - accuracy: 0.5973 - val_loss: 1.5312 - val_accuracy: 0.4528
# Epoch 20/200
# 34/34 [==============================] - 5s 137ms/step - loss: 1.1102 - accuracy: 0.6001 - val_loss: 1.5678 - val_accuracy: 0.4222
# Epoch 21/200
# 34/34 [==============================] - 5s 137ms/step - loss: 1.0958 - accuracy: 0.6018 - val_loss: 1.4486 - val_accuracy: 0.4972
# Epoch 22/200
# 34/34 [==============================] - 5s 137ms/step - loss: 1.1902 - accuracy: 0.5782 - val_loss: 1.6007 - val_accuracy: 0.4556
# Epoch 23/200
# 34/34 [==============================] - 5s 137ms/step - loss: 1.0900 - accuracy: 0.5935 - val_loss: 1.6165 - val_accuracy: 0.4528
# Epoch 24/200
# 34/34 [==============================] - 5s 138ms/step - loss: 1.0812 - accuracy: 0.6211 - val_loss: 1.6331 - val_accuracy: 0.4917
# Epoch 25/200
# 34/34 [==============================] - 5s 138ms/step - loss: 1.0682 - accuracy: 0.6152 - val_loss: 1.6092 - val_accuracy: 0.4361
# Epoch 26/200
# 34/34 [==============================] - 5s 138ms/step - loss: 0.9633 - accuracy: 0.6568 - val_loss: 1.6342 - val_accuracy: 0.5000
# Epoch 27/200
# 34/34 [==============================] - 5s 138ms/step - loss: 0.9643 - accuracy: 0.6634 - val_loss: 1.5982 - val_accuracy: 0.5139
# Epoch 28/200
# 34/34 [==============================] - 5s 138ms/step - loss: 0.9497 - accuracy: 0.6548 - val_loss: 1.5604 - val_accuracy: 0.5083
# Epoch 29/200
# 34/34 [==============================] - 5s 137ms/step - loss: 0.9441 - accuracy: 0.6649 - val_loss: 1.6377 - val_accuracy: 0.5278
# Epoch 30/200
# 34/34 [==============================] - 5s 138ms/step - loss: 0.9875 - accuracy: 0.6466 - val_loss: 1.9576 - val_accuracy: 0.4639
# Epoch 31/200
# 34/34 [==============================] - 5s 137ms/step - loss: 0.8584 - accuracy: 0.6881 - val_loss: 1.8707 - val_accuracy: 0.4583
# Epoch 32/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.9054 - accuracy: 0.6859 - val_loss: 1.6120 - val_accuracy: 0.5167
# Epoch 33/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.8873 - accuracy: 0.6965 - val_loss: 1.8080 - val_accuracy: 0.5111
# Epoch 34/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.8856 - accuracy: 0.6995 - val_loss: 1.9464 - val_accuracy: 0.4889
# Epoch 35/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.8375 - accuracy: 0.7160 - val_loss: 1.7811 - val_accuracy: 0.4722
# Epoch 36/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.7796 - accuracy: 0.7028 - val_loss: 1.6495 - val_accuracy: 0.5472
# Epoch 37/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.7504 - accuracy: 0.7356 - val_loss: 1.6782 - val_accuracy: 0.5194
# Epoch 38/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.8294 - accuracy: 0.6995 - val_loss: 1.8473 - val_accuracy: 0.5250
# Epoch 39/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.7460 - accuracy: 0.7257 - val_loss: 1.6828 - val_accuracy: 0.5389
# Epoch 40/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.7253 - accuracy: 0.7489 - val_loss: 1.9014 - val_accuracy: 0.5361
# Epoch 41/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.8011 - accuracy: 0.7068 - val_loss: 1.9102 - val_accuracy: 0.5083
# Epoch 42/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.7174 - accuracy: 0.7480 - val_loss: 1.9539 - val_accuracy: 0.4861
# Epoch 43/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.7279 - accuracy: 0.7446 - val_loss: 1.8370 - val_accuracy: 0.5083
# Epoch 44/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.6546 - accuracy: 0.7708 - val_loss: 1.8043 - val_accuracy: 0.5444
# Epoch 45/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.5990 - accuracy: 0.7735 - val_loss: 2.0225 - val_accuracy: 0.4917
# Epoch 46/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.6098 - accuracy: 0.7804 - val_loss: 2.1273 - val_accuracy: 0.5194
# Epoch 47/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.5786 - accuracy: 0.7947 - val_loss: 2.0717 - val_accuracy: 0.5250
# Epoch 48/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.5566 - accuracy: 0.8002 - val_loss: 2.0444 - val_accuracy: 0.5389
# Epoch 49/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.5433 - accuracy: 0.7941 - val_loss: 1.9124 - val_accuracy: 0.5500
# Epoch 50/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.5111 - accuracy: 0.8224 - val_loss: 1.8508 - val_accuracy: 0.5389
# Epoch 51/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.4978 - accuracy: 0.8198 - val_loss: 1.9810 - val_accuracy: 0.5500
# Epoch 52/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.5252 - accuracy: 0.8047 - val_loss: 2.0883 - val_accuracy: 0.5167
# Epoch 53/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.4578 - accuracy: 0.8545 - val_loss: 2.1175 - val_accuracy: 0.5111
# Epoch 54/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.4287 - accuracy: 0.8391 - val_loss: 2.1825 - val_accuracy: 0.5444
# Epoch 55/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.4201 - accuracy: 0.8554 - val_loss: 2.1239 - val_accuracy: 0.5250
# Epoch 56/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.3908 - accuracy: 0.8753 - val_loss: 2.3770 - val_accuracy: 0.5194
# Epoch 57/200
# 34/34 [==============================] - 5s 134ms/step - loss: 0.4252 - accuracy: 0.8360 - val_loss: 2.0716 - val_accuracy: 0.5417
# Epoch 58/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.3592 - accuracy: 0.8734 - val_loss: 1.9807 - val_accuracy: 0.5500
# Epoch 59/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.3788 - accuracy: 0.8757 - val_loss: 2.3664 - val_accuracy: 0.5333
# Epoch 60/200
# 34/34 [==============================] - 5s 137ms/step - loss: 0.3325 - accuracy: 0.8859 - val_loss: 2.3829 - val_accuracy: 0.5250
# Epoch 61/200
# 34/34 [==============================] - 5s 137ms/step - loss: 0.3060 - accuracy: 0.8878 - val_loss: 2.3036 - val_accuracy: 0.5389
# Epoch 62/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.3382 - accuracy: 0.8811 - val_loss: 2.1827 - val_accuracy: 0.5556
# Epoch 63/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.2851 - accuracy: 0.9005 - val_loss: 2.4433 - val_accuracy: 0.5250
# Epoch 64/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.3053 - accuracy: 0.8872 - val_loss: 2.5367 - val_accuracy: 0.5139
# Epoch 65/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.2594 - accuracy: 0.9085 - val_loss: 2.5039 - val_accuracy: 0.5167
# Epoch 66/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.2645 - accuracy: 0.9025 - val_loss: 2.3876 - val_accuracy: 0.5417
# Epoch 67/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.1999 - accuracy: 0.9390 - val_loss: 2.2996 - val_accuracy: 0.5611
# Epoch 68/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.2495 - accuracy: 0.8990 - val_loss: 2.1352 - val_accuracy: 0.5722
# Epoch 69/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.1920 - accuracy: 0.9313 - val_loss: 2.5687 - val_accuracy: 0.5583
# Epoch 70/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.2038 - accuracy: 0.9197 - val_loss: 2.4646 - val_accuracy: 0.5694
# Epoch 71/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.2010 - accuracy: 0.9255 - val_loss: 2.5238 - val_accuracy: 0.5806
# Epoch 72/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.2232 - accuracy: 0.9150 - val_loss: 2.2991 - val_accuracy: 0.5639
# Epoch 73/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.1792 - accuracy: 0.9305 - val_loss: 2.3452 - val_accuracy: 0.5694
# Epoch 74/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.1482 - accuracy: 0.9544 - val_loss: 2.4675 - val_accuracy: 0.5611
# Epoch 75/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.1432 - accuracy: 0.9603 - val_loss: 2.6022 - val_accuracy: 0.5556
# Epoch 76/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.1228 - accuracy: 0.9558 - val_loss: 2.3845 - val_accuracy: 0.5639
# Epoch 77/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.1343 - accuracy: 0.9581 - val_loss: 2.6622 - val_accuracy: 0.5444
# Epoch 78/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.1168 - accuracy: 0.9588 - val_loss: 2.4275 - val_accuracy: 0.5611
# Epoch 79/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.1056 - accuracy: 0.9736 - val_loss: 2.7757 - val_accuracy: 0.5528
# Epoch 80/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.1268 - accuracy: 0.9552 - val_loss: 2.8617 - val_accuracy: 0.5306
# Epoch 81/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.1005 - accuracy: 0.9672 - val_loss: 2.6885 - val_accuracy: 0.5528
# Epoch 82/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.1078 - accuracy: 0.9661 - val_loss: 2.6017 - val_accuracy: 0.5639
# Epoch 83/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.1087 - accuracy: 0.9673 - val_loss: 2.9251 - val_accuracy: 0.5528
# Epoch 84/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.1110 - accuracy: 0.9510 - val_loss: 2.8242 - val_accuracy: 0.5722
# Epoch 85/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.1142 - accuracy: 0.9602 - val_loss: 2.6888 - val_accuracy: 0.5861
# Epoch 86/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.0642 - accuracy: 0.9776 - val_loss: 3.2495 - val_accuracy: 0.5444
# Epoch 87/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.1233 - accuracy: 0.9511 - val_loss: 2.8470 - val_accuracy: 0.5611
# Epoch 88/200
# 34/34 [==============================] - 5s 137ms/step - loss: 0.0781 - accuracy: 0.9708 - val_loss: 2.9163 - val_accuracy: 0.5528
# Epoch 89/200
# 34/34 [==============================] - 5s 134ms/step - loss: 0.1159 - accuracy: 0.9610 - val_loss: 2.5568 - val_accuracy: 0.5917
# Epoch 90/200
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0726 - accuracy: 0.9723 - val_loss: 2.8006 - val_accuracy: 0.5528
# Epoch 91/200
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0734 - accuracy: 0.9885 - val_loss: 3.1147 - val_accuracy: 0.5444
# Epoch 92/200
# 34/34 [==============================] - 4s 132ms/step - loss: 0.0889 - accuracy: 0.9649 - val_loss: 2.8029 - val_accuracy: 0.5750
# Epoch 93/200
# 34/34 [==============================] - 4s 131ms/step - loss: 0.0642 - accuracy: 0.9802 - val_loss: 3.3804 - val_accuracy: 0.5556
# Epoch 94/200
# 34/34 [==============================] - 4s 130ms/step - loss: 0.0597 - accuracy: 0.9852 - val_loss: 2.8928 - val_accuracy: 0.5917
# Epoch 95/200
# 34/34 [==============================] - 4s 130ms/step - loss: 0.0414 - accuracy: 0.9827 - val_loss: 2.8182 - val_accuracy: 0.5722
# Epoch 96/200
# 34/34 [==============================] - 4s 129ms/step - loss: 0.0428 - accuracy: 0.9905 - val_loss: 3.1719 - val_accuracy: 0.5611
# Epoch 97/200
# 34/34 [==============================] - 4s 129ms/step - loss: 0.0642 - accuracy: 0.9794 - val_loss: 3.2079 - val_accuracy: 0.5861
# Epoch 98/200
# 34/34 [==============================] - 4s 129ms/step - loss: 0.0859 - accuracy: 0.9656 - val_loss: 3.0634 - val_accuracy: 0.5611
# Epoch 99/200
# 34/34 [==============================] - 4s 129ms/step - loss: 0.0424 - accuracy: 0.9859 - val_loss: 3.2715 - val_accuracy: 0.5444
# Epoch 100/200
# 34/34 [==============================] - 4s 129ms/step - loss: 0.0520 - accuracy: 0.9865 - val_loss: 2.9330 - val_accuracy: 0.5722
# Epoch 101/200
# 34/34 [==============================] - 4s 128ms/step - loss: 0.0571 - accuracy: 0.9812 - val_loss: 3.2521 - val_accuracy: 0.5583
# Epoch 102/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0788 - accuracy: 0.9706 - val_loss: 3.0374 - val_accuracy: 0.5611
# Epoch 103/200
# 34/34 [==============================] - 4s 126ms/step - loss: 0.0326 - accuracy: 0.9931 - val_loss: 3.1665 - val_accuracy: 0.5583
# Epoch 104/200
# 34/34 [==============================] - 4s 128ms/step - loss: 0.0617 - accuracy: 0.9822 - val_loss: 3.2216 - val_accuracy: 0.5694
# Epoch 105/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0558 - accuracy: 0.9829 - val_loss: 3.4376 - val_accuracy: 0.5583
# Epoch 106/200
# 34/34 [==============================] - 4s 128ms/step - loss: 0.0364 - accuracy: 0.9891 - val_loss: 3.1640 - val_accuracy: 0.5861
# Epoch 107/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0355 - accuracy: 0.9910 - val_loss: 3.0145 - val_accuracy: 0.5722
# Epoch 108/200
# 34/34 [==============================] - 4s 128ms/step - loss: 0.0295 - accuracy: 0.9943 - val_loss: 3.2365 - val_accuracy: 0.6167
# Epoch 109/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0705 - accuracy: 0.9857 - val_loss: 3.0629 - val_accuracy: 0.6083
# Epoch 110/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0440 - accuracy: 0.9860 - val_loss: 3.2839 - val_accuracy: 0.5694
# Epoch 111/200
# 34/34 [==============================] - 4s 128ms/step - loss: 0.0638 - accuracy: 0.9722 - val_loss: 3.4673 - val_accuracy: 0.5889
# Epoch 112/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0790 - accuracy: 0.9745 - val_loss: 3.1183 - val_accuracy: 0.6028
# Epoch 113/200
# 34/34 [==============================] - 4s 128ms/step - loss: 0.0579 - accuracy: 0.9805 - val_loss: 3.1390 - val_accuracy: 0.6056
# Epoch 114/200
# 34/34 [==============================] - 4s 128ms/step - loss: 0.0637 - accuracy: 0.9692 - val_loss: 3.3113 - val_accuracy: 0.5778
# Epoch 115/200
# 34/34 [==============================] - 4s 128ms/step - loss: 0.0459 - accuracy: 0.9896 - val_loss: 3.7169 - val_accuracy: 0.5750
# Epoch 116/200
# 34/34 [==============================] - 4s 126ms/step - loss: 0.0208 - accuracy: 0.9948 - val_loss: 3.5437 - val_accuracy: 0.5889
# Epoch 117/200
# 34/34 [==============================] - 4s 126ms/step - loss: 0.0381 - accuracy: 0.9864 - val_loss: 3.3693 - val_accuracy: 0.6194
# Epoch 118/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0665 - accuracy: 0.9849 - val_loss: 3.7679 - val_accuracy: 0.5889
# Epoch 119/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0507 - accuracy: 0.9791 - val_loss: 3.6732 - val_accuracy: 0.5444
# Epoch 120/200
# 34/34 [==============================] - 4s 128ms/step - loss: 0.0310 - accuracy: 0.9908 - val_loss: 3.4533 - val_accuracy: 0.5806
# Epoch 121/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0739 - accuracy: 0.9747 - val_loss: 3.2955 - val_accuracy: 0.5889
# Epoch 122/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0585 - accuracy: 0.9745 - val_loss: 3.7105 - val_accuracy: 0.5639
# Epoch 123/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0439 - accuracy: 0.9812 - val_loss: 3.5218 - val_accuracy: 0.5889
# Epoch 124/200
# 34/34 [==============================] - 4s 126ms/step - loss: 0.0308 - accuracy: 0.9926 - val_loss: 3.3472 - val_accuracy: 0.5944
# Epoch 125/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0200 - accuracy: 0.9928 - val_loss: 3.4840 - val_accuracy: 0.5806
# Epoch 126/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0164 - accuracy: 0.9946 - val_loss: 3.5287 - val_accuracy: 0.5500
# Epoch 127/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0247 - accuracy: 0.9896 - val_loss: 3.5235 - val_accuracy: 0.5667
# Epoch 128/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0349 - accuracy: 0.9856 - val_loss: 3.6409 - val_accuracy: 0.5639
# Epoch 129/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0374 - accuracy: 0.9848 - val_loss: 3.6691 - val_accuracy: 0.5778
# Epoch 130/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0256 - accuracy: 0.9919 - val_loss: 3.3631 - val_accuracy: 0.5722
# Epoch 131/200
# 34/34 [==============================] - 4s 128ms/step - loss: 0.0305 - accuracy: 0.9890 - val_loss: 3.5626 - val_accuracy: 0.5472
# Epoch 132/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.1029 - accuracy: 0.9746 - val_loss: 3.3876 - val_accuracy: 0.5694
# Epoch 133/200
# 34/34 [==============================] - 4s 128ms/step - loss: 0.0083 - accuracy: 0.9994 - val_loss: 3.7310 - val_accuracy: 0.5639
# Epoch 134/200
# 34/34 [==============================] - 4s 128ms/step - loss: 0.0370 - accuracy: 0.9869 - val_loss: 3.4826 - val_accuracy: 0.6056
# Epoch 135/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0133 - accuracy: 0.9969 - val_loss: 3.4481 - val_accuracy: 0.6139
# Epoch 136/200
# 34/34 [==============================] - 4s 128ms/step - loss: 0.0203 - accuracy: 0.9896 - val_loss: 3.4225 - val_accuracy: 0.6083
# Epoch 137/200
# 34/34 [==============================] - 4s 126ms/step - loss: 0.0350 - accuracy: 0.9894 - val_loss: 3.1459 - val_accuracy: 0.6139
# Epoch 138/200
# 34/34 [==============================] - 4s 126ms/step - loss: 0.0346 - accuracy: 0.9908 - val_loss: 3.4992 - val_accuracy: 0.5889
# Epoch 139/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0134 - accuracy: 0.9959 - val_loss: 3.7708 - val_accuracy: 0.5361
# Epoch 140/200
# 34/34 [==============================] - 4s 126ms/step - loss: 0.0570 - accuracy: 0.9822 - val_loss: 3.4690 - val_accuracy: 0.5944
# Epoch 141/200
# 34/34 [==============================] - 4s 128ms/step - loss: 0.0143 - accuracy: 0.9946 - val_loss: 3.5748 - val_accuracy: 0.5944
# Epoch 142/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0461 - accuracy: 0.9885 - val_loss: 3.6896 - val_accuracy: 0.5722
# Epoch 143/200
# 34/34 [==============================] - 4s 128ms/step - loss: 0.0373 - accuracy: 0.9872 - val_loss: 3.4325 - val_accuracy: 0.5833
# Epoch 144/200
# 34/34 [==============================] - 4s 128ms/step - loss: 0.0327 - accuracy: 0.9895 - val_loss: 3.4460 - val_accuracy: 0.6028
# Epoch 145/200
# 34/34 [==============================] - 4s 126ms/step - loss: 0.0233 - accuracy: 0.9937 - val_loss: 3.3977 - val_accuracy: 0.6167
# Epoch 146/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0244 - accuracy: 0.9906 - val_loss: 3.5691 - val_accuracy: 0.5972
# Epoch 147/200
# 34/34 [==============================] - 4s 126ms/step - loss: 0.0177 - accuracy: 0.9964 - val_loss: 3.5678 - val_accuracy: 0.5917
# Epoch 148/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0216 - accuracy: 0.9959 - val_loss: 3.6021 - val_accuracy: 0.5500
# Epoch 149/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0121 - accuracy: 0.9959 - val_loss: 3.4834 - val_accuracy: 0.5889
# Epoch 150/200
# 34/34 [==============================] - 4s 128ms/step - loss: 0.0236 - accuracy: 0.9910 - val_loss: 3.5929 - val_accuracy: 0.6083
# Epoch 151/200
# 34/34 [==============================] - 4s 128ms/step - loss: 0.0270 - accuracy: 0.9913 - val_loss: 3.7649 - val_accuracy: 0.5750
# Epoch 152/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0166 - accuracy: 0.9942 - val_loss: 3.5395 - val_accuracy: 0.5972
# Epoch 153/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0202 - accuracy: 0.9943 - val_loss: 3.4871 - val_accuracy: 0.6111
# Epoch 154/200
# 34/34 [==============================] - 4s 125ms/step - loss: 0.0179 - accuracy: 0.9923 - val_loss: 3.6781 - val_accuracy: 0.5972
# Epoch 155/200
# 34/34 [==============================] - 4s 124ms/step - loss: 0.0155 - accuracy: 0.9960 - val_loss: 3.9394 - val_accuracy: 0.5778
# Epoch 156/200
# 34/34 [==============================] - 4s 125ms/step - loss: 0.0609 - accuracy: 0.9850 - val_loss: 3.7409 - val_accuracy: 0.5889
# Epoch 157/200
# 34/34 [==============================] - 4s 126ms/step - loss: 0.0214 - accuracy: 0.9901 - val_loss: 3.7702 - val_accuracy: 0.5972
# Epoch 158/200
# 34/34 [==============================] - 4s 126ms/step - loss: 0.0077 - accuracy: 0.9971 - val_loss: 3.6566 - val_accuracy: 0.5833
# Epoch 159/200
# 34/34 [==============================] - 4s 125ms/step - loss: 0.0087 - accuracy: 0.9970 - val_loss: 3.6291 - val_accuracy: 0.5861
# Epoch 160/200
# 34/34 [==============================] - 4s 125ms/step - loss: 0.0125 - accuracy: 0.9957 - val_loss: 3.7880 - val_accuracy: 0.5750
# Epoch 161/200
# 34/34 [==============================] - 4s 125ms/step - loss: 0.0255 - accuracy: 0.9880 - val_loss: 3.7054 - val_accuracy: 0.6083
# Epoch 162/200
# 34/34 [==============================] - 4s 125ms/step - loss: 0.0247 - accuracy: 0.9926 - val_loss: 3.7222 - val_accuracy: 0.6056
# Epoch 163/200
# 34/34 [==============================] - 4s 126ms/step - loss: 0.0047 - accuracy: 0.9995 - val_loss: 3.6632 - val_accuracy: 0.5861
# Epoch 164/200
# 34/34 [==============================] - 4s 126ms/step - loss: 0.0023 - accuracy: 0.9999 - val_loss: 3.9515 - val_accuracy: 0.6000
# Epoch 165/200
# 34/34 [==============================] - 4s 126ms/step - loss: 0.0257 - accuracy: 0.9919 - val_loss: 3.6605 - val_accuracy: 0.6056
# Epoch 166/200
# 34/34 [==============================] - 4s 126ms/step - loss: 0.0176 - accuracy: 0.9924 - val_loss: 3.5946 - val_accuracy: 0.5833
# Epoch 167/200
# 34/34 [==============================] - 4s 125ms/step - loss: 0.0111 - accuracy: 0.9976 - val_loss: 3.9612 - val_accuracy: 0.5806
# Epoch 168/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0224 - accuracy: 0.9938 - val_loss: 3.8423 - val_accuracy: 0.5833
# Epoch 169/200
# 34/34 [==============================] - 4s 126ms/step - loss: 0.0206 - accuracy: 0.9941 - val_loss: 3.8127 - val_accuracy: 0.5972
# Epoch 170/200
# 34/34 [==============================] - 4s 125ms/step - loss: 0.0055 - accuracy: 0.9980 - val_loss: 3.7787 - val_accuracy: 0.5889
# Epoch 171/200
# 34/34 [==============================] - 4s 125ms/step - loss: 0.0248 - accuracy: 0.9898 - val_loss: 3.9392 - val_accuracy: 0.5806
# Epoch 172/200
# 34/34 [==============================] - 4s 124ms/step - loss: 0.0363 - accuracy: 0.9882 - val_loss: 3.8910 - val_accuracy: 0.5833
# Epoch 173/200
# 34/34 [==============================] - 4s 126ms/step - loss: 0.0219 - accuracy: 0.9921 - val_loss: 3.8793 - val_accuracy: 0.5750
# Epoch 174/200
# 34/34 [==============================] - 4s 126ms/step - loss: 0.0331 - accuracy: 0.9931 - val_loss: 3.8720 - val_accuracy: 0.5972
# Epoch 175/200
# 34/34 [==============================] - 4s 126ms/step - loss: 0.0046 - accuracy: 0.9989 - val_loss: 4.4752 - val_accuracy: 0.5806
# Epoch 176/200
# 34/34 [==============================] - 4s 125ms/step - loss: 0.0173 - accuracy: 0.9949 - val_loss: 3.8641 - val_accuracy: 0.6167
# Epoch 177/200
# 34/34 [==============================] - 4s 126ms/step - loss: 0.0085 - accuracy: 0.9976 - val_loss: 3.8845 - val_accuracy: 0.5833
# Epoch 178/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0467 - accuracy: 0.9884 - val_loss: 3.8966 - val_accuracy: 0.5778
# Epoch 179/200
# 34/34 [==============================] - 4s 128ms/step - loss: 0.0115 - accuracy: 0.9960 - val_loss: 3.7210 - val_accuracy: 0.5972
# Epoch 180/200
# 34/34 [==============================] - 4s 128ms/step - loss: 0.0148 - accuracy: 0.9949 - val_loss: 3.7919 - val_accuracy: 0.5972
# Epoch 181/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0139 - accuracy: 0.9924 - val_loss: 3.9058 - val_accuracy: 0.6083
# Epoch 182/200
# 34/34 [==============================] - 4s 128ms/step - loss: 0.0245 - accuracy: 0.9916 - val_loss: 3.7584 - val_accuracy: 0.6000
# Epoch 183/200
# 34/34 [==============================] - 4s 128ms/step - loss: 0.0097 - accuracy: 0.9969 - val_loss: 3.9754 - val_accuracy: 0.5944
# Epoch 184/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0202 - accuracy: 0.9938 - val_loss: 3.7755 - val_accuracy: 0.5917
# Epoch 185/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0069 - accuracy: 0.9986 - val_loss: 3.8736 - val_accuracy: 0.5917
# Epoch 186/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0237 - accuracy: 0.9878 - val_loss: 3.9824 - val_accuracy: 0.5944
# Epoch 187/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0044 - accuracy: 0.9993 - val_loss: 4.2992 - val_accuracy: 0.5889
# Epoch 188/200
# 34/34 [==============================] - 4s 129ms/step - loss: 0.0388 - accuracy: 0.9841 - val_loss: 3.7407 - val_accuracy: 0.6000
# Epoch 189/200
# 34/34 [==============================] - 4s 128ms/step - loss: 0.0142 - accuracy: 0.9936 - val_loss: 4.1853 - val_accuracy: 0.5667
# Epoch 190/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0135 - accuracy: 0.9927 - val_loss: 4.0085 - val_accuracy: 0.5972
# Epoch 191/200
# 34/34 [==============================] - 4s 128ms/step - loss: 0.0199 - accuracy: 0.9920 - val_loss: 4.0595 - val_accuracy: 0.5889
# Epoch 192/200
# 34/34 [==============================] - 4s 128ms/step - loss: 0.0055 - accuracy: 0.9987 - val_loss: 4.2005 - val_accuracy: 0.5778
# Epoch 193/200
# 34/34 [==============================] - 4s 128ms/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 4.1874 - val_accuracy: 0.6139
# Epoch 194/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0087 - accuracy: 0.9969 - val_loss: 4.1678 - val_accuracy: 0.5667
# Epoch 195/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0109 - accuracy: 0.9955 - val_loss: 4.2828 - val_accuracy: 0.5833
# Epoch 196/200
# 34/34 [==============================] - 4s 128ms/step - loss: 0.0102 - accuracy: 0.9973 - val_loss: 4.3333 - val_accuracy: 0.5611
# Epoch 197/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0106 - accuracy: 0.9979 - val_loss: 3.9551 - val_accuracy: 0.5750
# Epoch 198/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0294 - accuracy: 0.9895 - val_loss: 4.3797 - val_accuracy: 0.5806
# Epoch 199/200
# 34/34 [==============================] - 4s 128ms/step - loss: 0.0142 - accuracy: 0.9946 - val_loss: 4.3268 - val_accuracy: 0.5639
# Epoch 200/200
# 34/34 [==============================] - 4s 127ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 4.0809 - val_accuracy: 0.5806

# %%
print("Accuracy of our model on test data : " , model.evaluate(x_test,y_test)[1]*100 , "%")

epochs = [i for i in range(200)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
test_acc = history.history['val_accuracy']
test_loss = history.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()
# Out:
# 12/12 [==============================] - 1s 53ms/step - loss: 4.0809 - accuracy: 0.5806
# Accuracy of our model on test data :  58.05555582046509 %
